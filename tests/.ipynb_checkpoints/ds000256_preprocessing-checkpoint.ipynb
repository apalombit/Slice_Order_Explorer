# %%
# %matplotlib inline

# %%
import os, sys
import nibabel as nb
import numpy as np

from nipype import Node, Workflow
from nipype.interfaces.fsl import SliceTimer, MCFLIRT, Smooth, ExtractROI

import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.utils import shuffle

import glob
import shutil

# %%
def writer(MyList, tgtf):
    MyFile=open(tgtf,'w')
    MyList=map(lambda x:x+'\n', MyList)
    MyFile.writelines(MyList)
    MyFile.close()

def f_kendall(timeseries_matrix):

    """
    Calculates the Kendall's coefficient of concordance for a number of
    time-series in the input matrix
    Parameters
    ----------
    timeseries_matrix : ndarray
        A matrix of ranks of a subset subject's brain voxels
    Returns
    -------
    kcc : float
        Kendall's coefficient of concordance on the given input matrix
    """

    import numpy as np
    nk = timeseries_matrix.shape

    n = nk[0]
    k = nk[1]

    sr = np.sum(timeseries_matrix, 1)
    sr_bar = np.mean(sr)
    s = np.sum(np.power(sr, 2)) - n*np.power(sr_bar, 2)
    kcc = 12 *s/np.power(k, 2)/(np.power(n, 3) - n)
    return kcc

def compute_reho(in_file, mask_file, cluster_size = 7, out_file = None):

    """
    Computes the ReHo Map, by computing tied ranks of the timepoints,
    followed by computing Kendall's coefficient concordance(KCC) of a
    timeseries with its neighbours
    Parameters
    ----------
    in_file : nifti file
        4D EPI File
    mask_file : nifti file
        Mask of the EPI File(Only Compute ReHo of voxels in the mask)
    out_file : nifti file
        Where to save result
    cluster_size : integer
        for a brain voxel the number of neighbouring brain voxels to use for
        KCC.
    Returns
    -------
    out_file : nifti file
        ReHo map of the input EPI image
    """

    res_fname = (in_file)
    res_mask_fname = (mask_file)
    CUTNUMBER = 10

    if not (cluster_size == 27 or cluster_size == 19 or cluster_size == 7 or cluster_size == 18):
        cluster_size = 27

    nvoxel = cluster_size

    res_img = nb.load(res_fname)
    res_mask_img = nb.load(res_mask_fname)

    res_data = res_img.get_data()
    res_mask_data = res_mask_img.get_data()

    print(res_data.shape)
    (n_x, n_y, n_z, n_t) = res_data.shape

    # "flatten" each volume of the timeseries into one big array instead of
    # x,y,z - produces (timepoints, N voxels) shaped data array
    res_data = np.reshape(res_data, (n_x*n_y*n_z, n_t), order='F').T

    # create a blank array of zeroes of size n_voxels, one for each time point
    Ranks_res_data = np.tile((np.zeros((1, (res_data.shape)[1]))),
                             [(res_data.shape)[0], 1])

    # divide the number of total voxels by the cutnumber (set to 10)
    # ex. end up with a number in the thousands if there are tens of thousands
    # of voxels
    segment_length = np.ceil(float((res_data.shape)[1])/float(CUTNUMBER))

    for icut in range(0, CUTNUMBER):

        segment = None

        # create a Numpy array of evenly spaced values from the segment
        # starting point up until the segment_length integer
        if not (icut == (CUTNUMBER - 1)):
            segment = np.array(np.arange(icut * segment_length,
                                         (icut+1) * segment_length))
        else:
            segment = np.array(np.arange(icut * segment_length,
                                         (res_data.shape[1])))

        segment = np.int64(segment[np.newaxis])

        # res_data_piece is a chunk of the original timeseries in_file, but
        # aligned with the current segment index spacing
        res_data_piece = res_data[:, segment[0]]
        nvoxels_piece = res_data_piece.shape[1]

        # run a merge sort across the time axis, re-ordering the flattened
        # volume voxel arrays
        res_data_sorted = np.sort(res_data_piece, 0, kind='mergesort')
        sort_index = np.argsort(res_data_piece, axis=0, kind='mergesort')

        # subtract each volume from each other
        db = np.diff(res_data_sorted, 1, 0)

        # convert any zero voxels into "True" flag
        db = db == 0

        # return an n_voxel (n voxels within the current segment) sized array
        # of values, each value being the sum total of TRUE values in "db"
        sumdb = np.sum(db, 0)

        temp_array = np.array(np.arange(0, n_t))
        temp_array = temp_array[:, np.newaxis]

        sorted_ranks = np.tile(temp_array, [1, nvoxels_piece])

        if np.any(sumdb[:]):

            tie_adjust_index = np.flatnonzero(sumdb)

            for i in range(0, len(tie_adjust_index)):

                ranks = sorted_ranks[:, tie_adjust_index[i]]

                ties = db[:, tie_adjust_index[i]]

                tieloc = np.append(np.flatnonzero(ties), n_t + 2)
                maxties = len(tieloc)
                tiecount = 0

                while(tiecount < maxties -1):
                    tiestart = tieloc[tiecount]
                    ntied = 2
                    while(tieloc[tiecount + 1] == (tieloc[tiecount] + 1)):
                        tiecount += 1
                        ntied += 1

                    ranks[tiestart:tiestart + ntied] = np.ceil(np.float32(np.sum(ranks[tiestart:tiestart + ntied ]))/np.float32(ntied))
                    tiecount += 1

                sorted_ranks[:, tie_adjust_index[i]] = ranks

        del db, sumdb
        sort_index_base = np.tile(np.multiply(np.arange(0, nvoxels_piece), n_t), [n_t, 1])
        sort_index += sort_index_base
        del sort_index_base

        ranks_piece = np.zeros((n_t, nvoxels_piece))

        ranks_piece = ranks_piece.flatten(order='F')
        sort_index = sort_index.flatten(order='F')
        sorted_ranks = sorted_ranks.flatten(order='F')

        ranks_piece[sort_index] = np.array(sorted_ranks)

        ranks_piece = np.reshape(ranks_piece, (n_t, nvoxels_piece), order='F')

        del sort_index, sorted_ranks

        Ranks_res_data[:, segment[0]] = ranks_piece

        sys.stdout.write('.')

    Ranks_res_data = np.reshape(Ranks_res_data, (n_t, n_x, n_y, n_z), order='F')

    K = np.zeros((n_x, n_y, n_z))

    mask_cluster = np.ones((3, 3, 3))

    if nvoxel == 19:
        mask_cluster[0, 0, 0] = 0
        mask_cluster[0, 2, 0] = 0
        mask_cluster[2, 0, 0] = 0
        mask_cluster[2, 2, 0] = 0
        mask_cluster[0, 0, 2] = 0
        mask_cluster[0, 2, 2] = 0
        mask_cluster[2, 0, 2] = 0
        mask_cluster[2, 2, 2] = 0
        
    elif nvoxel == 18:
        # null mid disk and disky-shaped
        mask_cluster[0, 0, 0] = 0
        mask_cluster[0, 2, 0] = 0
        mask_cluster[2, 0, 0] = 0
        mask_cluster[2, 2, 0] = 0
        mask_cluster[0, 0, 2] = 0
        mask_cluster[0, 2, 2] = 0
        mask_cluster[2, 0, 2] = 0
        mask_cluster[2, 2, 2] = 0
        mask_cluster[1, 0, 0] = 0
        mask_cluster[1, 0, 1] = 0
        mask_cluster[1, 0, 2] = 0
        mask_cluster[1, 2, 0] = 0
        mask_cluster[1, 2, 1] = 0
        mask_cluster[1, 2, 2] = 0
        mask_cluster[1, 1, 0] = 0
        mask_cluster[1, 1, 2] = 0

    elif nvoxel == 7:

        mask_cluster[0, 0, 0] = 0
        mask_cluster[0, 1, 0] = 0
        mask_cluster[0, 2, 0] = 0
        mask_cluster[0, 0, 1] = 0
        mask_cluster[0, 2, 1] = 0
        mask_cluster[0, 0, 2] = 0
        mask_cluster[0, 1, 2] = 0
        mask_cluster[0, 2, 2] = 0
        mask_cluster[1, 0, 0] = 0
        mask_cluster[1, 2, 0] = 0
        mask_cluster[1, 0, 2] = 0
        mask_cluster[1, 2, 2] = 0
        mask_cluster[2, 0, 0] = 0
        mask_cluster[2, 1, 0] = 0
        mask_cluster[2, 2, 0] = 0
        mask_cluster[2, 0, 1] = 0
        mask_cluster[2, 2, 1] = 0
        mask_cluster[2, 0, 2] = 0
        mask_cluster[2, 1, 2] = 0
        mask_cluster[2, 2, 2] = 0

    for i in range(1, n_x - 1):
        for j in range(1, n_y -1):
            for k in range(1, n_z -1):

                block = Ranks_res_data[:, i-1:i+2, j-1:j+2, k-1:k+2]
                mask_block = res_mask_data[i-1:i+2, j-1:j+2, k-1:k+2]

                if not(int(mask_block[1, 1, 1]) == 0):

                    if nvoxel == 19 or nvoxel == 7 or nvoxel == 18:
                        mask_block = np.multiply(mask_block, mask_cluster)

                    R_block = np.reshape(block, (block.shape[0], 27),
                                         order='F')
                    mask_R_block = R_block[:, np.argwhere(np.reshape(mask_block, (1, 27), order='F') > 0)[:, 1]]

                    K[i, j, k] = f_kendall(mask_R_block)

    img = nb.Nifti1Image(K, header=res_img.get_header(),
                         affine=res_img.get_affine())
    
    if out_file is not None:
        reho_file = out_file
    else:
        reho_file = os.path.join(os.getcwd(), 'ReHo.nii.gz')
    img.to_filename(reho_file)
    
    return reho_file

# %%
base = "/Volumes/G_drive/Backup_06062020/ds000256/"
order_path = base + "/SlTi/"
 
sbjpatt  = ""
sess     = "func"
fmriname = "_task-restbaseline_bold.nii.gz"

# %%
TR    = 2.5
fwhm  = 3
dummy = 10
n_sl  = 32
rh    = 18 #27

# %%
# https://en.wikibooks.org/wiki/SPM/Slice_Timing

os.makedirs(order_path, mode=777, exist_ok=True)

# seq asc 1 2 3 4
slice_order = list(np.arange(1, n_sl+1).astype(str))
writer(slice_order, order_path + 'slti_1.txt') 

# seq desc 4 3 2 1
slice_order = list(reversed(list(np.arange(1, n_sl+1).astype(str))))
writer(slice_order, order_path + 'slti_2.txt') 

# int asc 1 3 2 4
slice_order = list(np.arange(1, n_sl+1, 2).astype(str)) + list(np.arange(2, n_sl+1, 2).astype(str))
writer(slice_order, order_path + 'slti_3.txt') 

# int desc 4 2 3 1
slice_order = list(reversed(list(np.arange(1, n_sl+1, 2).astype(str)) + list(np.arange(2, n_sl+1, 2).astype(str))))
writer(slice_order, order_path + 'slti_4.txt') 

# int2 asc 2 4 1 3
slice_order = list(np.arange(2, n_sl+1, 2).astype(str)) + list(np.arange(1, n_sl+1, 2).astype(str))
writer(slice_order, order_path + 'slti_5.txt') 

# int2 dsc 3 1 4 2
slice_order = list(reversed(list(np.arange(2, n_sl+1, 2).astype(str)) + list(np.arange(1, n_sl+1, 2).astype(str))))
writer(slice_order, order_path + 'slti_6.txt') 

n_last = 12 # how many "noise" permutation to use
for rr in np.arange(7,n_last):
    slice_order = list(shuffle(np.arange(1, n_sl+1).astype(str), random_state=rr))
    writer(slice_order, order_path + 'slti_{}.txt'.format(rr)) # random permutation of slices

# %%
rehos = []
for sbj in sorted([sbj.split("/")[-1].replace("sub-","") for sbj in glob.glob(base + "sub-{}*".format(sbjpatt))]):
    fmri_nii = base + "sub-{}/{}/".format(sbj,sess) + "sub-{}{}".format(sbj,fmriname)
    for opt in np.arange(1, n_last):
        proc_ref   = '{}_preproc_{}'.format(sbj,opt)
        extract    = Node(ExtractROI(t_min=dummy, t_size=-1, output_type='NIFTI_GZ'), name="extract")
        slicetimer = Node(SliceTimer(custom_order = order_path + "slti_{}.txt".format(opt), time_repetition=TR), name="slicetimer")
        mcflirt    = Node(MCFLIRT(mean_vol=True, save_plots=True), name="mcflirt")
        smooth     = Node(Smooth(fwhm=fwhm), name="smooth")
        preproc01  = Workflow(name=proc_ref, base_dir=base)
        preproc01.connect([(extract,    slicetimer, [('roi_file', 'in_file')]),
                           (slicetimer, mcflirt,    [('slice_time_corrected_file', 'in_file')]),
                           (mcflirt,    smooth,     [('out_file', 'in_file')])])
        extract.inputs.in_file = fmri_nii
        preproc01.run('MultiProc', plugin_args={'n_procs': 1})
        
        basepath = base + "/{}/smooth/".format(proc_ref)
        proc_f   = basepath + fmri_nii.split("/")[-1].replace(".nii.gz","") + "_roi_st_mcf_smooth.nii.gz"
        in_f     = basepath + "meanvol"
        out_f    = basepath + "meanvol_bet"
        # !fslmaths {proc_f} -Tmean {in_f}
        # !bet {in_f} {out_f} -m
        
        rehos.append([sbj, opt, compute_reho(proc_f, in_f + "_bet" + "_mask.nii.gz", rh, out_file = base + "/" + sbj + "_" + str(opt) + "_ReHo.nii.gz")])
        shutil.rmtree(base + "/{}/".format(proc_ref))
# Out:
# 200607-16:55:38,991 nipype.workflow INFO:
# 	 Workflow CTS200_preproc_1 settings: ['check', 'execution', 'logging', 'monitoring']
# 200607-16:55:39,0 nipype.workflow INFO:
# 	 Running in parallel.
# 200607-16:55:39,4 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-16:55:39,77 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_1.extract" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_1/extract".
# 200607-16:55:39,89 nipype.workflow INFO:
# 	 [Node] Running "extract" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/G_drive/Backup_06062020/ds000256/sub-CTS200/func/sub-CTS200_task-restbaseline_bold.nii.gz /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_1/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz 10 -1
# 200607-16:55:41,8 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_1.extract
# 200607-16:55:43,305 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_1.extract".
# 200607-16:55:45,11 nipype.workflow INFO:
# 	 [Job 0] Completed (CTS200_preproc_1.extract).
# 200607-16:55:45,14 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-16:55:45,98 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_1.slicetimer" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_1/slicetimer".
# 200607-16:55:45,107 nipype.workflow INFO:
# 	 [Node] Running "slicetimer" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_1/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz --ocustom=/Volumes/G_drive/Backup_06062020/ds000256/SlTi/slti_1.txt --out=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_1/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz --repeat=2.500000
# 200607-16:55:47,12 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_1.slicetimer
# 200607-16:55:53,862 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_1.slicetimer".
# 200607-16:55:55,19 nipype.workflow INFO:
# 	 [Job 1] Completed (CTS200_preproc_1.slicetimer).
# 200607-16:55:55,21 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-16:55:55,71 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_1.mcflirt" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_1/mcflirt".
# 200607-16:55:55,81 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_1/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz -meanvol -out /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_1/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -plots
# 200607-16:55:57,24 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_1.mcflirt
# 200607-16:56:56,936 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_1.mcflirt".
# 200607-16:56:57,115 nipype.workflow INFO:
# 	 [Job 2] Completed (CTS200_preproc_1.mcflirt).
# 200607-16:56:57,117 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-16:56:57,166 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_1.smooth" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_1/smooth".
# 200607-16:56:57,174 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.fsl.utils.Smooth"), a CommandLine Interface with command:
# fslmaths /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_1/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -kernel gauss 1.274 -fmean sub-CTS200_task-restbaseline_bold_roi_st_mcf_smooth.nii.gz
# 200607-16:56:59,115 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_1.smooth
# 200607-16:57:03,582 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_1.smooth".
# 200607-16:57:05,127 nipype.workflow INFO:
# 	 [Job 3] Completed (CTS200_preproc_1.smooth).
# 200607-16:57:05,129 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# (64, 64, 32, 154)
# ..........200607-16:57:17,304 nipype.workflow INFO:
# 	 Workflow CTS200_preproc_2 settings: ['check', 'execution', 'logging', 'monitoring']
# 200607-16:57:17,310 nipype.workflow INFO:
# 	 Running in parallel.
# 200607-16:57:17,313 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:251: DeprecationWarning: get_header method is deprecated.
# Please use the ``img.header`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:252: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# 200607-16:57:17,378 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_2.extract" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_2/extract".
# 200607-16:57:17,392 nipype.workflow INFO:
# 	 [Node] Running "extract" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/G_drive/Backup_06062020/ds000256/sub-CTS200/func/sub-CTS200_task-restbaseline_bold.nii.gz /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_2/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz 10 -1
# 200607-16:57:19,316 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_2.extract
# 200607-16:57:21,516 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_2.extract".
# 200607-16:57:23,322 nipype.workflow INFO:
# 	 [Job 0] Completed (CTS200_preproc_2.extract).
# 200607-16:57:23,325 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-16:57:23,406 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_2.slicetimer" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_2/slicetimer".
# 200607-16:57:23,413 nipype.workflow INFO:
# 	 [Node] Running "slicetimer" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_2/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz --ocustom=/Volumes/G_drive/Backup_06062020/ds000256/SlTi/slti_2.txt --out=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_2/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz --repeat=2.500000
# 200607-16:57:25,324 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_2.slicetimer
# 200607-16:57:32,389 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_2.slicetimer".
# 200607-16:57:33,335 nipype.workflow INFO:
# 	 [Job 1] Completed (CTS200_preproc_2.slicetimer).
# 200607-16:57:33,337 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-16:57:33,397 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_2.mcflirt" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_2/mcflirt".
# 200607-16:57:33,405 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_2/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz -meanvol -out /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_2/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -plots
# 200607-16:57:35,337 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_2.mcflirt
# 200607-16:58:35,931 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_2.mcflirt".
# 200607-16:58:37,396 nipype.workflow INFO:
# 	 [Job 2] Completed (CTS200_preproc_2.mcflirt).
# 200607-16:58:37,399 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-16:58:37,447 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_2.smooth" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_2/smooth".
# 200607-16:58:37,465 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.fsl.utils.Smooth"), a CommandLine Interface with command:
# fslmaths /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_2/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -kernel gauss 1.274 -fmean sub-CTS200_task-restbaseline_bold_roi_st_mcf_smooth.nii.gz
# 200607-16:58:39,399 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_2.smooth
# 200607-16:58:43,949 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_2.smooth".
# 200607-16:58:45,406 nipype.workflow INFO:
# 	 [Job 3] Completed (CTS200_preproc_2.smooth).
# 200607-16:58:45,408 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# (64, 64, 32, 154)
# ..........
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:251: DeprecationWarning: get_header method is deprecated.
# Please use the ``img.header`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:252: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# 200607-16:58:57,951 nipype.workflow INFO:
# 	 Workflow CTS200_preproc_3 settings: ['check', 'execution', 'logging', 'monitoring']
# 200607-16:58:57,960 nipype.workflow INFO:
# 	 Running in parallel.
# 200607-16:58:57,963 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-16:58:58,36 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_3.extract" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_3/extract".
# 200607-16:58:58,48 nipype.workflow INFO:
# 	 [Node] Running "extract" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/G_drive/Backup_06062020/ds000256/sub-CTS200/func/sub-CTS200_task-restbaseline_bold.nii.gz /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_3/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz 10 -1
# 200607-16:58:59,967 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_3.extract
# 200607-16:59:02,327 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_3.extract".
# 200607-16:59:03,974 nipype.workflow INFO:
# 	 [Job 0] Completed (CTS200_preproc_3.extract).
# 200607-16:59:03,976 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-16:59:04,58 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_3.slicetimer" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_3/slicetimer".
# 200607-16:59:04,66 nipype.workflow INFO:
# 	 [Node] Running "slicetimer" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_3/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz --ocustom=/Volumes/G_drive/Backup_06062020/ds000256/SlTi/slti_3.txt --out=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_3/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz --repeat=2.500000
# 200607-16:59:05,975 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_3.slicetimer
# 200607-16:59:12,944 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_3.slicetimer".
# 200607-16:59:13,981 nipype.workflow INFO:
# 	 [Job 1] Completed (CTS200_preproc_3.slicetimer).
# 200607-16:59:13,983 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-16:59:14,33 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_3.mcflirt" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_3/mcflirt".
# 200607-16:59:14,40 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_3/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz -meanvol -out /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_3/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -plots
# 200607-16:59:15,983 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_3.mcflirt
# 200607-17:00:17,35 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_3.mcflirt".
# 200607-17:00:18,69 nipype.workflow INFO:
# 	 [Job 2] Completed (CTS200_preproc_3.mcflirt).
# 200607-17:00:18,72 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:00:18,116 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_3.smooth" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_3/smooth".
# 200607-17:00:18,124 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.fsl.utils.Smooth"), a CommandLine Interface with command:
# fslmaths /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_3/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -kernel gauss 1.274 -fmean sub-CTS200_task-restbaseline_bold_roi_st_mcf_smooth.nii.gz
# 200607-17:00:20,75 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_3.smooth
# 200607-17:00:24,768 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_3.smooth".
# 200607-17:00:26,80 nipype.workflow INFO:
# 	 [Job 3] Completed (CTS200_preproc_3.smooth).
# 200607-17:00:26,82 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# (64, 64, 32, 154)
# ..........200607-17:00:38,241 nipype.workflow INFO:
# 	 Workflow CTS200_preproc_4 settings: ['check', 'execution', 'logging', 'monitoring']
# 200607-17:00:38,250 nipype.workflow INFO:
# 	 Running in parallel.
# 200607-17:00:38,253 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:251: DeprecationWarning: get_header method is deprecated.
# Please use the ``img.header`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:252: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# 200607-17:00:38,326 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_4.extract" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_4/extract".
# 200607-17:00:38,337 nipype.workflow INFO:
# 	 [Node] Running "extract" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/G_drive/Backup_06062020/ds000256/sub-CTS200/func/sub-CTS200_task-restbaseline_bold.nii.gz /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_4/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz 10 -1
# 200607-17:00:40,259 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_4.extract
# 200607-17:00:42,554 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_4.extract".
# 200607-17:00:44,264 nipype.workflow INFO:
# 	 [Job 0] Completed (CTS200_preproc_4.extract).
# 200607-17:00:44,267 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:00:44,342 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_4.slicetimer" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_4/slicetimer".
# 200607-17:00:44,350 nipype.workflow INFO:
# 	 [Node] Running "slicetimer" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_4/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz --ocustom=/Volumes/G_drive/Backup_06062020/ds000256/SlTi/slti_4.txt --out=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_4/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz --repeat=2.500000
# 200607-17:00:46,265 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_4.slicetimer
# 200607-17:00:53,456 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_4.slicetimer".
# 200607-17:00:54,271 nipype.workflow INFO:
# 	 [Job 1] Completed (CTS200_preproc_4.slicetimer).
# 200607-17:00:54,273 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:00:54,323 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_4.mcflirt" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_4/mcflirt".
# 200607-17:00:54,331 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_4/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz -meanvol -out /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_4/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -plots
# 200607-17:00:56,271 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_4.mcflirt
# 200607-17:01:57,51 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_4.mcflirt".
# 200607-17:01:58,354 nipype.workflow INFO:
# 	 [Job 2] Completed (CTS200_preproc_4.mcflirt).
# 200607-17:01:58,357 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:01:58,413 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_4.smooth" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_4/smooth".
# 200607-17:01:58,422 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.fsl.utils.Smooth"), a CommandLine Interface with command:
# fslmaths /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_4/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -kernel gauss 1.274 -fmean sub-CTS200_task-restbaseline_bold_roi_st_mcf_smooth.nii.gz
# 200607-17:02:00,357 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_4.smooth
# 200607-17:02:04,848 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_4.smooth".
# 200607-17:02:06,367 nipype.workflow INFO:
# 	 [Job 3] Completed (CTS200_preproc_4.smooth).
# 200607-17:02:06,369 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# (64, 64, 32, 154)
# ..........200607-17:02:18,431 nipype.workflow INFO:
# 	 Workflow CTS200_preproc_5 settings: ['check', 'execution', 'logging', 'monitoring']
# 200607-17:02:18,439 nipype.workflow INFO:
# 	 Running in parallel.
# 200607-17:02:18,443 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:251: DeprecationWarning: get_header method is deprecated.
# Please use the ``img.header`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:252: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# 200607-17:02:18,513 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_5.extract" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_5/extract".
# 200607-17:02:18,525 nipype.workflow INFO:
# 	 [Node] Running "extract" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/G_drive/Backup_06062020/ds000256/sub-CTS200/func/sub-CTS200_task-restbaseline_bold.nii.gz /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_5/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz 10 -1
# 200607-17:02:20,449 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_5.extract
# 200607-17:02:22,685 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_5.extract".
# 200607-17:02:24,452 nipype.workflow INFO:
# 	 [Job 0] Completed (CTS200_preproc_5.extract).
# 200607-17:02:24,455 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:02:24,532 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_5.slicetimer" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_5/slicetimer".
# 200607-17:02:24,541 nipype.workflow INFO:
# 	 [Node] Running "slicetimer" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_5/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz --ocustom=/Volumes/G_drive/Backup_06062020/ds000256/SlTi/slti_5.txt --out=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_5/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz --repeat=2.500000
# 200607-17:02:26,456 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_5.slicetimer
# 200607-17:02:33,790 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_5.slicetimer".
# 200607-17:02:34,466 nipype.workflow INFO:
# 	 [Job 1] Completed (CTS200_preproc_5.slicetimer).
# 200607-17:02:34,469 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:02:34,521 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_5.mcflirt" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_5/mcflirt".
# 200607-17:02:34,528 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_5/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz -meanvol -out /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_5/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -plots
# 200607-17:02:36,468 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_5.mcflirt
# 200607-17:03:36,519 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_5.mcflirt".
# 200607-17:03:36,553 nipype.workflow INFO:
# 	 [Job 2] Completed (CTS200_preproc_5.mcflirt).
# 200607-17:03:36,555 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:03:36,606 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_5.smooth" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_5/smooth".
# 200607-17:03:36,614 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.fsl.utils.Smooth"), a CommandLine Interface with command:
# fslmaths /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_5/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -kernel gauss 1.274 -fmean sub-CTS200_task-restbaseline_bold_roi_st_mcf_smooth.nii.gz
# 200607-17:03:38,558 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_5.smooth
# 200607-17:03:43,419 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_5.smooth".
# 200607-17:03:44,560 nipype.workflow INFO:
# 	 [Job 3] Completed (CTS200_preproc_5.smooth).
# 200607-17:03:44,563 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# (64, 64, 32, 154)
# ..........200607-17:03:56,862 nipype.workflow INFO:
# 	 Workflow CTS200_preproc_6 settings: ['check', 'execution', 'logging', 'monitoring']
# 200607-17:03:56,872 nipype.workflow INFO:
# 	 Running in parallel.
# 200607-17:03:56,875 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:251: DeprecationWarning: get_header method is deprecated.
# Please use the ``img.header`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:252: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# 200607-17:03:56,946 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_6.extract" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_6/extract".
# 200607-17:03:56,957 nipype.workflow INFO:
# 	 [Node] Running "extract" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/G_drive/Backup_06062020/ds000256/sub-CTS200/func/sub-CTS200_task-restbaseline_bold.nii.gz /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_6/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz 10 -1
# 200607-17:03:58,877 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_6.extract
# 200607-17:04:01,184 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_6.extract".
# 200607-17:04:02,880 nipype.workflow INFO:
# 	 [Job 0] Completed (CTS200_preproc_6.extract).
# 200607-17:04:02,883 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:04:02,960 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_6.slicetimer" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_6/slicetimer".
# 200607-17:04:02,967 nipype.workflow INFO:
# 	 [Node] Running "slicetimer" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_6/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz --ocustom=/Volumes/G_drive/Backup_06062020/ds000256/SlTi/slti_6.txt --out=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_6/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz --repeat=2.500000
# 200607-17:04:04,885 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_6.slicetimer
# 200607-17:04:12,10 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_6.slicetimer".
# 200607-17:04:12,890 nipype.workflow INFO:
# 	 [Job 1] Completed (CTS200_preproc_6.slicetimer).
# 200607-17:04:12,892 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:04:12,941 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_6.mcflirt" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_6/mcflirt".
# 200607-17:04:12,948 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_6/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz -meanvol -out /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_6/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -plots
# 200607-17:04:14,894 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_6.mcflirt
# 200607-17:05:14,708 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_6.mcflirt".
# 200607-17:05:14,969 nipype.workflow INFO:
# 	 [Job 2] Completed (CTS200_preproc_6.mcflirt).
# 200607-17:05:14,972 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:05:15,22 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_6.smooth" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_6/smooth".
# 200607-17:05:15,29 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.fsl.utils.Smooth"), a CommandLine Interface with command:
# fslmaths /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_6/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -kernel gauss 1.274 -fmean sub-CTS200_task-restbaseline_bold_roi_st_mcf_smooth.nii.gz
# 200607-17:05:16,970 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_6.smooth
# 200607-17:05:21,945 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_6.smooth".
# 200607-17:05:22,976 nipype.workflow INFO:
# 	 [Job 3] Completed (CTS200_preproc_6.smooth).
# 200607-17:05:22,978 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# (64, 64, 32, 154)
# ..........200607-17:05:35,284 nipype.workflow INFO:
# 	 Workflow CTS200_preproc_7 settings: ['check', 'execution', 'logging', 'monitoring']
# 200607-17:05:35,292 nipype.workflow INFO:
# 	 Running in parallel.
# 200607-17:05:35,295 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:251: DeprecationWarning: get_header method is deprecated.
# Please use the ``img.header`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:252: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# 200607-17:05:35,359 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_7.extract" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_7/extract".
# 200607-17:05:35,370 nipype.workflow INFO:
# 	 [Node] Running "extract" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/G_drive/Backup_06062020/ds000256/sub-CTS200/func/sub-CTS200_task-restbaseline_bold.nii.gz /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_7/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz 10 -1
# 200607-17:05:37,299 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_7.extract
# 200607-17:05:39,968 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_7.extract".
# 200607-17:05:41,302 nipype.workflow INFO:
# 	 [Job 0] Completed (CTS200_preproc_7.extract).
# 200607-17:05:41,305 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:05:41,390 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_7.slicetimer" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_7/slicetimer".
# 200607-17:05:41,398 nipype.workflow INFO:
# 	 [Node] Running "slicetimer" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_7/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz --ocustom=/Volumes/G_drive/Backup_06062020/ds000256/SlTi/slti_7.txt --out=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_7/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz --repeat=2.500000
# 200607-17:05:43,308 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_7.slicetimer
# 200607-17:05:50,246 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_7.slicetimer".
# 200607-17:05:51,322 nipype.workflow INFO:
# 	 [Job 1] Completed (CTS200_preproc_7.slicetimer).
# 200607-17:05:51,325 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:05:51,373 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_7.mcflirt" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_7/mcflirt".
# 200607-17:05:51,381 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_7/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz -meanvol -out /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_7/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -plots
# 200607-17:05:53,324 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_7.mcflirt
# 200607-17:06:52,560 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_7.mcflirt".
# 200607-17:06:53,405 nipype.workflow INFO:
# 	 [Job 2] Completed (CTS200_preproc_7.mcflirt).
# 200607-17:06:53,408 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:06:53,458 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_7.smooth" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_7/smooth".
# 200607-17:06:53,466 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.fsl.utils.Smooth"), a CommandLine Interface with command:
# fslmaths /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_7/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -kernel gauss 1.274 -fmean sub-CTS200_task-restbaseline_bold_roi_st_mcf_smooth.nii.gz
# 200607-17:06:55,411 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_7.smooth
# 200607-17:07:00,444 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_7.smooth".
# 200607-17:07:01,416 nipype.workflow INFO:
# 	 [Job 3] Completed (CTS200_preproc_7.smooth).
# 200607-17:07:01,418 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# (64, 64, 32, 154)
# ..........
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:251: DeprecationWarning: get_header method is deprecated.
# Please use the ``img.header`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:252: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# 200607-17:07:14,184 nipype.workflow INFO:
# 	 Workflow CTS200_preproc_8 settings: ['check', 'execution', 'logging', 'monitoring']
# 200607-17:07:14,190 nipype.workflow INFO:
# 	 Running in parallel.
# 200607-17:07:14,193 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:07:14,268 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_8.extract" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_8/extract".
# 200607-17:07:14,279 nipype.workflow INFO:
# 	 [Node] Running "extract" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/G_drive/Backup_06062020/ds000256/sub-CTS200/func/sub-CTS200_task-restbaseline_bold.nii.gz /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_8/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz 10 -1
# 200607-17:07:16,200 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_8.extract
# 200607-17:07:18,431 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_8.extract".
# 200607-17:07:20,200 nipype.workflow INFO:
# 	 [Job 0] Completed (CTS200_preproc_8.extract).
# 200607-17:07:20,204 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:07:20,282 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_8.slicetimer" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_8/slicetimer".
# 200607-17:07:20,290 nipype.workflow INFO:
# 	 [Node] Running "slicetimer" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_8/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz --ocustom=/Volumes/G_drive/Backup_06062020/ds000256/SlTi/slti_8.txt --out=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_8/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz --repeat=2.500000
# 200607-17:07:22,200 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_8.slicetimer
# 200607-17:07:29,466 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_8.slicetimer".
# 200607-17:07:30,216 nipype.workflow INFO:
# 	 [Job 1] Completed (CTS200_preproc_8.slicetimer).
# 200607-17:07:30,218 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:07:30,267 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_8.mcflirt" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_8/mcflirt".
# 200607-17:07:30,275 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_8/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz -meanvol -out /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_8/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -plots
# 200607-17:07:32,219 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_8.mcflirt
# 200607-17:08:33,345 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_8.mcflirt".
# 200607-17:08:34,300 nipype.workflow INFO:
# 	 [Job 2] Completed (CTS200_preproc_8.mcflirt).
# 200607-17:08:34,302 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:08:34,360 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_8.smooth" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_8/smooth".
# 200607-17:08:34,391 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.fsl.utils.Smooth"), a CommandLine Interface with command:
# fslmaths /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_8/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -kernel gauss 1.274 -fmean sub-CTS200_task-restbaseline_bold_roi_st_mcf_smooth.nii.gz
# 200607-17:08:36,305 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_8.smooth
# 200607-17:08:41,770 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_8.smooth".
# 200607-17:08:42,316 nipype.workflow INFO:
# 	 [Job 3] Completed (CTS200_preproc_8.smooth).
# 200607-17:08:42,318 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# (64, 64, 32, 154)
# ..........
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:251: DeprecationWarning: get_header method is deprecated.
# Please use the ``img.header`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:252: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# 200607-17:08:56,303 nipype.workflow INFO:
# 	 Workflow CTS200_preproc_9 settings: ['check', 'execution', 'logging', 'monitoring']
# 200607-17:08:56,313 nipype.workflow INFO:
# 	 Running in parallel.
# 200607-17:08:56,316 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:08:56,388 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_9.extract" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_9/extract".
# 200607-17:08:56,399 nipype.workflow INFO:
# 	 [Node] Running "extract" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/G_drive/Backup_06062020/ds000256/sub-CTS200/func/sub-CTS200_task-restbaseline_bold.nii.gz /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_9/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz 10 -1
# 200607-17:08:58,321 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_9.extract
# 200607-17:09:01,2 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_9.extract".
# 200607-17:09:02,323 nipype.workflow INFO:
# 	 [Job 0] Completed (CTS200_preproc_9.extract).
# 200607-17:09:02,326 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:09:02,405 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_9.slicetimer" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_9/slicetimer".
# 200607-17:09:02,413 nipype.workflow INFO:
# 	 [Node] Running "slicetimer" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_9/extract/sub-CTS200_task-restbaseline_bold_roi.nii.gz --ocustom=/Volumes/G_drive/Backup_06062020/ds000256/SlTi/slti_9.txt --out=/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_9/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz --repeat=2.500000
# 200607-17:09:04,328 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_9.slicetimer
# 200607-17:09:11,533 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_9.slicetimer".
# 200607-17:09:12,330 nipype.workflow INFO:
# 	 [Job 1] Completed (CTS200_preproc_9.slicetimer).
# 200607-17:09:12,333 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:09:12,380 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_9.mcflirt" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_9/mcflirt".
# 200607-17:09:12,387 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_9/slicetimer/sub-CTS200_task-restbaseline_bold_roi_st.nii.gz -meanvol -out /Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_9/mcflirt/sub-CTS200_task-restbaseline_bold_roi_st_mcf.nii.gz -plots
# 200607-17:09:14,336 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS200_preproc_9.mcflirt
# 200607-17:10:14,133 nipype.workflow INFO:
# 	 [Node] Finished "CTS200_preproc_9.mcflirt".
# 200607-17:10:14,428 nipype.workflow INFO:
# 	 [Job 2] Completed (CTS200_preproc_9.mcflirt).
# 200607-17:10:14,431 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-17:10:14,481 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS200_preproc_9.smooth" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS200_preproc_9/smooth".
# 200607-17:10:14,508 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.fsl.utils.Smooth"), a CommandLine Interface with command:
# ...
# 200607-18:04:49,884 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.fsl.utils.Smooth"), a CommandLine Interface with command:
# fslmaths /Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_8/mcflirt/sub-CTS203_task-restbaseline_bold_roi_st_mcf.nii.gz -kernel gauss 1.274 -fmean sub-CTS203_task-restbaseline_bold_roi_st_mcf_smooth.nii.gz
# 200607-18:04:51,803 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS203_preproc_8.smooth
# 200607-18:04:56,715 nipype.workflow INFO:
# 	 [Node] Finished "CTS203_preproc_8.smooth".
# 200607-18:04:57,809 nipype.workflow INFO:
# 	 [Job 3] Completed (CTS203_preproc_8.smooth).
# 200607-18:04:57,812 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# (64, 64, 32, 154)
# ..........
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:251: DeprecationWarning: get_header method is deprecated.
# Please use the ``img.header`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:252: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# 200607-18:05:10,427 nipype.workflow INFO:
# 	 Workflow CTS203_preproc_9 settings: ['check', 'execution', 'logging', 'monitoring']
# 200607-18:05:10,436 nipype.workflow INFO:
# 	 Running in parallel.
# 200607-18:05:10,442 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-18:05:10,534 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS203_preproc_9.extract" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_9/extract".
# 200607-18:05:10,548 nipype.workflow INFO:
# 	 [Node] Running "extract" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/G_drive/Backup_06062020/ds000256/sub-CTS203/func/sub-CTS203_task-restbaseline_bold.nii.gz /Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_9/extract/sub-CTS203_task-restbaseline_bold_roi.nii.gz 10 -1
# 200607-18:05:12,446 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS203_preproc_9.extract
# 200607-18:05:15,14 nipype.workflow INFO:
# 	 [Node] Finished "CTS203_preproc_9.extract".
# 200607-18:05:16,446 nipype.workflow INFO:
# 	 [Job 0] Completed (CTS203_preproc_9.extract).
# 200607-18:05:16,449 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-18:05:16,541 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS203_preproc_9.slicetimer" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_9/slicetimer".
# 200607-18:05:16,549 nipype.workflow INFO:
# 	 [Node] Running "slicetimer" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_9/extract/sub-CTS203_task-restbaseline_bold_roi.nii.gz --ocustom=/Volumes/G_drive/Backup_06062020/ds000256/SlTi/slti_9.txt --out=/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_9/slicetimer/sub-CTS203_task-restbaseline_bold_roi_st.nii.gz --repeat=2.500000
# 200607-18:05:18,447 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS203_preproc_9.slicetimer
# 200607-18:05:25,514 nipype.workflow INFO:
# 	 [Node] Finished "CTS203_preproc_9.slicetimer".
# 200607-18:05:26,459 nipype.workflow INFO:
# 	 [Job 1] Completed (CTS203_preproc_9.slicetimer).
# 200607-18:05:26,461 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-18:05:26,508 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS203_preproc_9.mcflirt" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_9/mcflirt".
# 200607-18:05:26,516 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_9/slicetimer/sub-CTS203_task-restbaseline_bold_roi_st.nii.gz -meanvol -out /Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_9/mcflirt/sub-CTS203_task-restbaseline_bold_roi_st_mcf.nii.gz -plots
# 200607-18:05:28,460 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS203_preproc_9.mcflirt
# 200607-18:06:29,408 nipype.workflow INFO:
# 	 [Node] Finished "CTS203_preproc_9.mcflirt".
# 200607-18:06:30,547 nipype.workflow INFO:
# 	 [Job 2] Completed (CTS203_preproc_9.mcflirt).
# 200607-18:06:30,549 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-18:06:30,593 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS203_preproc_9.smooth" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_9/smooth".
# 200607-18:06:30,619 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.fsl.utils.Smooth"), a CommandLine Interface with command:
# fslmaths /Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_9/mcflirt/sub-CTS203_task-restbaseline_bold_roi_st_mcf.nii.gz -kernel gauss 1.274 -fmean sub-CTS203_task-restbaseline_bold_roi_st_mcf_smooth.nii.gz
# 200607-18:06:32,552 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS203_preproc_9.smooth
# 200607-18:06:37,604 nipype.workflow INFO:
# 	 [Node] Finished "CTS203_preproc_9.smooth".
# 200607-18:06:38,564 nipype.workflow INFO:
# 	 [Job 3] Completed (CTS203_preproc_9.smooth).
# 200607-18:06:38,566 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# (64, 64, 32, 154)
# ..........
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:251: DeprecationWarning: get_header method is deprecated.
# Please use the ``img.header`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:252: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# 200607-18:06:51,491 nipype.workflow INFO:
# 	 Workflow CTS203_preproc_10 settings: ['check', 'execution', 'logging', 'monitoring']
# 200607-18:06:51,540 nipype.workflow INFO:
# 	 Running in parallel.
# 200607-18:06:51,544 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-18:06:51,613 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS203_preproc_10.extract" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_10/extract".
# 200607-18:06:51,625 nipype.workflow INFO:
# 	 [Node] Running "extract" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/G_drive/Backup_06062020/ds000256/sub-CTS203/func/sub-CTS203_task-restbaseline_bold.nii.gz /Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_10/extract/sub-CTS203_task-restbaseline_bold_roi.nii.gz 10 -1
# 200607-18:06:53,546 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS203_preproc_10.extract
# 200607-18:06:56,212 nipype.workflow INFO:
# 	 [Node] Finished "CTS203_preproc_10.extract".
# 200607-18:06:57,550 nipype.workflow INFO:
# 	 [Job 0] Completed (CTS203_preproc_10.extract).
# 200607-18:06:57,554 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-18:06:57,660 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS203_preproc_10.slicetimer" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_10/slicetimer".
# 200607-18:06:57,671 nipype.workflow INFO:
# 	 [Node] Running "slicetimer" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_10/extract/sub-CTS203_task-restbaseline_bold_roi.nii.gz --ocustom=/Volumes/G_drive/Backup_06062020/ds000256/SlTi/slti_10.txt --out=/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_10/slicetimer/sub-CTS203_task-restbaseline_bold_roi_st.nii.gz --repeat=2.500000
# 200607-18:06:59,551 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS203_preproc_10.slicetimer
# 200607-18:07:07,59 nipype.workflow INFO:
# 	 [Node] Finished "CTS203_preproc_10.slicetimer".
# 200607-18:07:07,560 nipype.workflow INFO:
# 	 [Job 1] Completed (CTS203_preproc_10.slicetimer).
# 200607-18:07:07,564 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-18:07:07,622 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS203_preproc_10.mcflirt" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_10/mcflirt".
# 200607-18:07:07,630 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_10/slicetimer/sub-CTS203_task-restbaseline_bold_roi_st.nii.gz -meanvol -out /Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_10/mcflirt/sub-CTS203_task-restbaseline_bold_roi_st_mcf.nii.gz -plots
# 200607-18:07:09,565 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS203_preproc_10.mcflirt
# 200607-18:08:10,826 nipype.workflow INFO:
# 	 [Node] Finished "CTS203_preproc_10.mcflirt".
# 200607-18:08:11,649 nipype.workflow INFO:
# 	 [Job 2] Completed (CTS203_preproc_10.mcflirt).
# 200607-18:08:11,651 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-18:08:11,707 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS203_preproc_10.smooth" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_10/smooth".
# 200607-18:08:11,729 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.fsl.utils.Smooth"), a CommandLine Interface with command:
# fslmaths /Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_10/mcflirt/sub-CTS203_task-restbaseline_bold_roi_st_mcf.nii.gz -kernel gauss 1.274 -fmean sub-CTS203_task-restbaseline_bold_roi_st_mcf_smooth.nii.gz
# 200607-18:08:13,655 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS203_preproc_10.smooth
# 200607-18:08:18,626 nipype.workflow INFO:
# 	 [Node] Finished "CTS203_preproc_10.smooth".
# 200607-18:08:19,660 nipype.workflow INFO:
# 	 [Job 3] Completed (CTS203_preproc_10.smooth).
# 200607-18:08:19,662 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# (64, 64, 32, 154)
# ..........
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:251: DeprecationWarning: get_header method is deprecated.
# Please use the ``img.header`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# /Users/ale/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:252: DeprecationWarning: get_affine method is deprecated.
# Please use the ``img.affine`` property instead.
#
# * deprecated from version: 2.1
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 4.0
# 200607-18:08:32,961 nipype.workflow INFO:
# 	 Workflow CTS203_preproc_11 settings: ['check', 'execution', 'logging', 'monitoring']
# 200607-18:08:32,975 nipype.workflow INFO:
# 	 Running in parallel.
# 200607-18:08:32,979 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-18:08:33,64 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS203_preproc_11.extract" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_11/extract".
# 200607-18:08:33,79 nipype.workflow INFO:
# 	 [Node] Running "extract" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Volumes/G_drive/Backup_06062020/ds000256/sub-CTS203/func/sub-CTS203_task-restbaseline_bold.nii.gz /Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_11/extract/sub-CTS203_task-restbaseline_bold_roi.nii.gz 10 -1
# 200607-18:08:34,982 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS203_preproc_11.extract
# 200607-18:08:37,889 nipype.workflow INFO:
# 	 [Node] Finished "CTS203_preproc_11.extract".
# 200607-18:08:38,984 nipype.workflow INFO:
# 	 [Job 0] Completed (CTS203_preproc_11.extract).
# 200607-18:08:38,987 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-18:08:39,69 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS203_preproc_11.slicetimer" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_11/slicetimer".
# 200607-18:08:39,77 nipype.workflow INFO:
# 	 [Node] Running "slicetimer" ("nipype.interfaces.fsl.preprocess.SliceTimer"), a CommandLine Interface with command:
# slicetimer --in=/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_11/extract/sub-CTS203_task-restbaseline_bold_roi.nii.gz --ocustom=/Volumes/G_drive/Backup_06062020/ds000256/SlTi/slti_11.txt --out=/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_11/slicetimer/sub-CTS203_task-restbaseline_bold_roi_st.nii.gz --repeat=2.500000
# 200607-18:08:40,985 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS203_preproc_11.slicetimer
# 200607-18:08:47,984 nipype.workflow INFO:
# 	 [Node] Finished "CTS203_preproc_11.slicetimer".
# 200607-18:08:48,991 nipype.workflow INFO:
# 	 [Job 1] Completed (CTS203_preproc_11.slicetimer).
# 200607-18:08:48,994 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 3.60/3.60, Free processors: 1/1.
# 200607-18:08:49,37 nipype.workflow INFO:
# 	 [Node] Setting-up "CTS203_preproc_11.mcflirt" in "/Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_11/mcflirt".
# 200607-18:08:49,45 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_11/slicetimer/sub-CTS203_task-restbaseline_bold_roi_st.nii.gz -meanvol -out /Volumes/G_drive/Backup_06062020/ds000256/CTS203_preproc_11/mcflirt/sub-CTS203_task-restbaseline_bold_roi_st_mcf.nii.gz -plots
# 200607-18:08:50,995 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.40/3.60, Free processors: 0/1.
#                      Currently running:
#                        * CTS203_preproc_11.mcflirt

# %%
rehos = [[ff.split("/")[-1].split("_")[0], ff.split("/")[-1].split("_")[1], ff] for ff in glob.glob(base+"*_ReHo.nii.gz")]

# %%
thr = 0.05
res = pd.DataFrame(columns=['sbj', 'ord', 'rehoavg', 'rehopct'])
for nii in rehos:
    img = nb.load(nii[-1]).get_fdata()
    img = img.ravel()
    img = img[img>thr]    
    if int(nii[1]) < 7:
        res = res.append({"sbj":nii[0], "ord":nii[1], "rehoavg":np.nanmean(img), "rehopct":np.percentile(img,90)}, ignore_index = True)
    else:
        res = res.append({"sbj":nii[0], "ord":"0",      "rehoavg":np.nanmean(img), "rehopct":np.percentile(img,90)}, ignore_index = True)

# %%
metric = "rehopct"

signif = pd.DataFrame(columns=['sbj', 'ord', 'reho', 'tt'])
for sbj in np.unique(res.sbj.values):
    rsel = res[res.sbj == sbj].sort_values(["rehopct","rehoavg"])
    
    for oo in np.arange(0,7):
        oo = str(oo)
        t2 = (np.nanmean(rsel[rsel.ord == oo][metric].values - np.nanmean(rsel[rsel.ord == "0"][metric].values))) / \
            np.nanstd(rsel[rsel.ord == "0"][metric].values)
        signif = signif.append({"sbj":sbj, 
                                "ord":oo, 
                                "reho":round(np.nanmean(rsel[rsel.ord == oo][metric].values),3), 
                                "tt": round(np.abs(t2), 3)}, ignore_index = True)

#signif = signif[(signif.ord != "5") & (signif.ord != "6")] # exclude impossible cases

lls = []
for sbj in np.unique(res.sbj.values):
    rsel = signif[signif.sbj == sbj].sort_values(["reho","sbj"])
    lls.append(rsel[rsel.sbj==sbj].iloc[-1:].ord.values[:])

# %%
x  = np.array(lls).astype(int).ravel()
y  = np.bincount(x)
ii = np.nonzero(y)[0]
print("ord_id, counts")
np.vstack((ii,y[ii])).T
# Out:
# ord_id, counts
# array([[5, 1]])

# %%
signif.sort_values(["sbj", "tt"]).head(10)
# Out:
#       sbj ord   reho     tt
# 0  CTS200   0  0.326  0.000
# 6  CTS200   6  0.326  0.105
# 3  CTS200   3  0.326  0.544
# 1  CTS200   1  0.327  0.703
# 2  CTS200   2  0.328  1.109
# 5  CTS200   5  0.328  1.598
# 4  CTS200   4  0.328  1.855
